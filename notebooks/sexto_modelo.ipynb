# %% [markdown]
# #### Aquí encontrarás todo lo que necesitas saber: https://www.kaggle.com/competitions/precio-portatiles-the-bridge/overview

# %% [markdown]
# ## Librerias

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from Funciones import *

# %% [markdown]
# ## Data

# %% [markdown]
# - Variable a predecir: Price_euros
#
# - Variables predictoras: por defenir
#
# - Variables a desechar: laptop_ID,

# %%
df_test = pd.read_csv('../data/test.csv', index_col=0)
df_test
# Out:
#       laptop_ID Company                                Product  \
# id
# 181        1098      HP                           Spectre x360
# 708         330    Acer                               Aspire 5
# 862        1260    Acer                         Aspire ES1-572
# 1064       1137      HP                         EliteBook 1040
# 702        1015      HP                                 ENVY -
# ...         ...     ...                                    ...
# 1281        145  Lenovo                     Legion Y520-15IKBN
# 524        1195  Lenovo                     IdeaPad Y700-15ISK
# 1015       1070      HP                                 250 G5
# 1236        104      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon
# 1036        258  Lenovo                         Yoga 920-13IKB
#
#                 TypeName  Inches                           ScreenResolution  \
# id
# 181            Ultrabook    13.3            IPS Panel 4K Ultra HD 3840x2160
# 708             Notebook    15.6                                   1366x768
# 862             Notebook    15.6                                   1366x768
# 1064            Notebook    14.0                          Full HD 1920x1080
# 702             Notebook    13.3                IPS Panel Full HD 1920x1080
# ...                  ...     ...                                        ...
# 1281              Gaming    15.6                IPS Panel Full HD 1920x1080
# 524               Gaming    15.6                IPS Panel Full HD 1920x1080
# 1015            Notebook    15.6                                   1366x768
# 1236            Notebook    15.6                          Full HD 1920x1080
# 1036  2 in 1 Convertible    13.9  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                Cpu   Ram     Memory                       Gpu  \
# id
# 181     Intel Core i7 7500U 2.7GHz  16GB  512GB SSD     Intel HD Graphics 620
# 708    AMD A12-Series 9720P 2.7GHz   8GB  256GB SSD         AMD Radeon RX 540
# 862     Intel Core i3 6006U 2.0GHz   4GB  500GB HDD     Intel HD Graphics 520
# 1064    Intel Core i5 6200U 2.3GHz   8GB  256GB SSD     Intel HD Graphics 520
# 702     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD     Intel HD Graphics 620
# ...                            ...   ...        ...                       ...
# 1281   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD  Nvidia GeForce GTX 1050M
# 524    Intel Core i7 6700HQ 2.6GHz  16GB  512GB SSD    Nvidia GeForce GTX 960
# 1015    Intel Core i5 7200U 2.5GHz   4GB  500GB HDD     Intel HD Graphics 620
# 1236  AMD E-Series E2-9000e 1.5GHz   4GB  500GB HDD             AMD Radeon R2
# 1036    Intel Core i7 8550U 1.8GHz   8GB  512GB SSD    Intel UHD Graphics 620
#
#            OpSys  Weight
# id
# 181   Windows 10   1.3kg
# 708   Windows 10   2.2kg
# 862        Linux   2.4kg
# 1064   Windows 7  1.43kg
# 702   Windows 10  1.34kg
# ...          ...     ...
# 1281       No OS   2.4kg
# 524   Windows 10  3.31kg
# 1015       No OS  1.96kg
# 1236  Windows 10   2.1kg
# 1036  Windows 10  1.37kg
#
# [391 rows x 12 columns]

# %%
df_train = pd.read_csv('../data/train.csv', index_col=0)
df_train
# Out:
#       laptop_ID  Company                     Product            TypeName  \
# id
# 268        1002     Dell               Inspiron 5567            Notebook
# 347         867     Asus  X541NA (N4200/4GB/1TB/W10)            Notebook
# 353         966  Toshiba           Portege Z30-C-1CW            Notebook
# 578         767     Dell                Alienware 17              Gaming
# 42         1241     Dell              Latitude E7270           Ultrabook
# ...         ...      ...                         ...                 ...
# 89          973     Acer       Chromebook C738T-C2EJ  2 in 1 Convertible
# 716        1018  Toshiba           Portege Z30-C-16H            Notebook
# 517        1071     Acer              Aspire ES1-523            Notebook
# 891         965     Dell               Latitude 7480           Ultrabook
# 1179       1313     Dell               Inspiron 3567            Notebook
#
#       Inches                 ScreenResolution  \
# id
# 268     15.6                         1366x768
# 347     15.6                         1366x768
# 353     13.3                Full HD 1920x1080
# 578     15.6  IPS Panel 4K Ultra HD 3840x2160
# 42      12.5  Full HD / Touchscreen 1920x1080
# ...      ...                              ...
# 89      11.6   IPS Panel Touchscreen 1366x768
# 716     13.3                Full HD 1920x1080
# 517     15.6                         1366x768
# 891     14.0                Full HD 1920x1080
# 1179    15.6                         1366x768
#
#                                        Cpu   Ram                Memory  \
# id
# 268             Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 347   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 353             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 578            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 42              Intel Core i5 6300U 2.4GHz   8GB             256GB SSD
# ...                                    ...   ...                   ...
# 89    Intel Celeron Dual Core N3060 1.6GHz   4GB    32GB Flash Storage
# 716             Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 517              AMD A8-Series 7410 2.2GHz   8GB               1TB HDD
# 891             Intel Core i7 7600U 2.8GHz   8GB             256GB SSD
# 1179            Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# id
# 268        AMD Radeon R7 M445  Windows 10  2.36kg       749.00
# 347     Intel HD Graphics 505  Windows 10     2kg       449.00
# 353     Intel HD Graphics 520   Windows 7   1.2kg      1460.00
# 578   Nvidia GeForce GTX 1070  Windows 10  4.42kg      2868.99
# 42      Intel HD Graphics 520   Windows 7  1.26kg      1713.37
# ...                       ...         ...     ...          ...
# 89      Intel HD Graphics 400   Chrome OS  1.25kg       389.00
# 716     Intel HD Graphics 520  Windows 10   1.2kg      1195.00
# 517             AMD Radeon R5  Windows 10   2.4kg       449.00
# 891     Intel HD Graphics 620  Windows 10  1.36kg      1775.00
# 1179       AMD Radeon R5 M430       Linux   2.3kg       805.99
#
# [912 rows x 13 columns]

# %%
sample = pd.read_csv('../data/sample_submission.csv')
sample
# Out:
#        id  Price_euros
# 0    1014        752.0
# 1     845        499.0
# 2    1151       1747.0
# 3    1265        245.0
# 4     573       1179.0
# ..    ...          ...
# 386  1162        258.0
# 387  1286       1085.0
# 388   336        298.0
# 389   885       1099.0
# 390  1246       1339.0
#
# [391 rows x 2 columns]

# %% [markdown]
# ## Data exploration

# %%
df_train['TypeName'].nunique()
# Out:
# 6

# %%
df_train['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              522
# Gaming                138
# Ultrabook             135
# 2 in 1 Convertible     85
# Workstation            18
# Netbook                14
# Name: count, dtype: int64

# %%
df_train['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      746
# Linux            47
# No OS            44
# Windows 7        32
# Chrome OS        20
# macOS            11
# Mac OS X          6
# Windows 10 S      4
# Android           2
# Name: count, dtype: int64

# %% [markdown]
# ## Data processing

# %% [markdown]
# ## Test

# %%
# Para este primer modelo voy a limpiar algunas columnas y cambiar su dtype

#Primero ram
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').astype(int)

# Ahora voy a transformar Weight
df_test['Weight'] = df_test['Weight'].str.replace('kg', '').astype(float)

# Voy a renombar  Weight y le pondré Weigh/kg para que sea más descriptiva y se entienda que los valores numericos hacen referencia a su peso en kg

df_test = df_test.rename(columns={'Weight': 'Weight/kg'})

# %%
print (df_test.columns)
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys',
#        'Weight/kg'],
#       dtype='object')

# %%
# Me haré un segundo DF donde desecho las primeras dos columnas porque no las necesito para la predicción

df_test2 = df_test.drop(['laptop_ID'], axis=1)

# Voy a ver si puedo sacarle provecho al typeName
# df2_t = df2_t.drop(['TypeName'], axis=1)

# %%
print (df_test2.columns)
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu',
#        'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight/kg'],
#       dtype='object')

# %%
# Función que agrupa OS
def group_os(name):
    if 'Windows' in name:
        return 'Windows'
    elif re.search(r'mac', name, re.IGNORECASE):
        return 'Mac'
    elif name in ['Linux', 'Chrome OS', 'Android']:
        return 'Other OS'
    else:
        return 'No OS/Other'

# %%
df_test2['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              205
# Gaming                 67
# Ultrabook              61
# 2 in 1 Convertible     36
# Workstation            11
# Netbook                11
# Name: count, dtype: int64

# %%
# Agrupo varias variables
df_test2['OpSys_Grouped'] = df_test2['OpSys'].apply(group_os)
df_test2['Company_Grouped'] = df_test2['Company'].apply(agrupar_marcas)

# %%
# #  Aplicar One-Hot Encoding a la variable TypeName, al ser tan pocos no hizo falta agruparlos primero
# df_encoded_test = pd.get_dummies(df2_t, columns=['TypeName', "OpSys_Grouped", "Company_Grouped"])

# %%
df_test2['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                161
# 1366x768                                          73
# IPS Panel Full HD 1920x1080                       67
# IPS Panel Full HD / Touchscreen 1920x1080         16
# Full HD / Touchscreen 1920x1080                   15
# 1600x900                                          12
# Quad HD+ / Touchscreen 3200x1800                   7
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      3
# Touchscreen 2560x1440                              3
# Touchscreen 2256x1504                              3
# IPS Panel Quad HD+ / Touchscreen 3200x1800         2
# 4K Ultra HD 3840x2160                              2
# 1440x900                                           2
# IPS Panel Quad HD+ 2560x1440                       2
# 4K Ultra HD / Touchscreen 3840x2160                2
# IPS Panel Touchscreen 1366x768                     2
# IPS Panel 4K Ultra HD 3840x2160                    2
# IPS Panel 1366x768                                 2
# IPS Panel Retina Display 2560x1600                 1
# 2560x1440                                          1
# IPS Panel Retina Display 2880x1800                 1
# IPS Panel Quad HD+ 3200x1800                       1
# IPS Panel 2560x1440                                1
# IPS Panel Full HD 2160x1440                        1
# IPS Panel Touchscreen 2560x1440                    1
# IPS Panel Full HD 1366x768                         1
# Quad HD+ 3200x1800                                 1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen 2400x1600                              1
# Touchscreen 1366x768                               1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
# Extraigo los pixeles
def extraer_pixeles(resolucion):
    # Busca dos números separados por 'x' o 'X'
    match = re.search(r'(\d+)x(\d+)', resolucion, re.IGNORECASE)
    if match:
        ancho, alto = map(int, match.groups())
        return ancho * alto
    else:
        return None  # O un valor por defecto, como 0 o -1

# %%
# Función extrae los screen featuring
def screen_featuring(row):
    ips = 'IPS' in row
    touchscreen = 'Touchscreen' in row
    return pd.Series([ips, touchscreen])

# %%
# Extraer los píxeles
df_test2['Pixeles_Total'] = df_test2['ScreenResolution'].apply(extraer_pixeles)

# Extraer características de la pantalla
df_test2[['IPS', 'Touchscreen']] = df_test2['ScreenResolution'].apply(screen_featuring)

# %%
# #  Aplicar One-Hot Encoding a la variable TypeName, al ser tan pocos no hizo falta agruparlos primero
# # df_encoded_test = pd.get_dummies(df2_t, columns=['TypeName', "OpSys_Grouped", "Company_Grouped"])
df_encoded_test = pd.get_dummies(df_test2, columns=['TypeName'])
df_encoded_test
# Out:
#      Company                                Product  Inches  \
# id
# 181       HP                           Spectre x360    13.3
# 708     Acer                               Aspire 5    15.6
# 862     Acer                         Aspire ES1-572    15.6
# 1064      HP                         EliteBook 1040    14.0
# 702       HP                                 ENVY -    13.3
# ...      ...                                    ...     ...
# 1281  Lenovo                     Legion Y520-15IKBN    15.6
# 524   Lenovo                     IdeaPad Y700-15ISK    15.6
# 1015      HP                                 250 G5    15.6
# 1236      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon    15.6
# 1036  Lenovo                         Yoga 920-13IKB    13.9
#
#                                ScreenResolution                           Cpu  \
# id
# 181             IPS Panel 4K Ultra HD 3840x2160    Intel Core i7 7500U 2.7GHz
# 708                                    1366x768   AMD A12-Series 9720P 2.7GHz
# 862                                    1366x768    Intel Core i3 6006U 2.0GHz
# 1064                          Full HD 1920x1080    Intel Core i5 6200U 2.3GHz
# 702                 IPS Panel Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# ...                                         ...                           ...
# 1281                IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
# 524                 IPS Panel Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 1015                                   1366x768    Intel Core i5 7200U 2.5GHz
# 1236                          Full HD 1920x1080  AMD E-Series E2-9000e 1.5GHz
# 1036  IPS Panel Full HD / Touchscreen 1920x1080    Intel Core i7 8550U 1.8GHz
#
#       Ram     Memory                       Gpu       OpSys  Weight/kg  ...  \
# id                                                                     ...
# 181    16  512GB SSD     Intel HD Graphics 620  Windows 10       1.30  ...
# 708     8  256GB SSD         AMD Radeon RX 540  Windows 10       2.20  ...
# 862     4  500GB HDD     Intel HD Graphics 520       Linux       2.40  ...
# 1064    8  256GB SSD     Intel HD Graphics 520   Windows 7       1.43  ...
# 702     8  256GB SSD     Intel HD Graphics 620  Windows 10       1.34  ...
# ...   ...        ...                       ...         ...        ...  ...
# 1281    8  256GB SSD  Nvidia GeForce GTX 1050M       No OS       2.40  ...
# 524    16  512GB SSD    Nvidia GeForce GTX 960  Windows 10       3.31  ...
# 1015    4  500GB HDD     Intel HD Graphics 620       No OS       1.96  ...
# 1236    4  500GB HDD             AMD Radeon R2  Windows 10       2.10  ...
# 1036    8  512GB SSD    Intel UHD Graphics 620  Windows 10       1.37  ...
#
#      Company_Grouped Pixeles_Total    IPS  Touchscreen  \
# id
# 181               HP       8294400   True        False
# 708             Acer       1049088  False        False
# 862             Acer       1049088  False        False
# 1064              HP       2073600  False        False
# 702               HP       2073600   True        False
# ...              ...           ...    ...          ...
# 1281          Lenovo       2073600   True        False
# 524           Lenovo       2073600   True        False
# 1015              HP       1049088  False        False
# 1236              HP       2073600  False        False
# 1036          Lenovo       2073600   True         True
#
#       TypeName_2 in 1 Convertible  TypeName_Gaming  TypeName_Netbook  \
# id
# 181                         False            False             False
# 708                         False            False             False
# 862                         False            False             False
# 1064                        False            False             False
# 702                         False            False             False
# ...                           ...              ...               ...
# 1281                        False             True             False
# 524                         False             True             False
# 1015                        False            False             False
# 1236                        False            False             False
# 1036                         True            False             False
#
#       TypeName_Notebook  TypeName_Ultrabook  TypeName_Workstation
# id
# 181               False                True                 False
# 708                True               False                 False
# 862                True               False                 False
# 1064               True               False                 False
# 702                True               False                 False
# ...                 ...                 ...                   ...
# 1281              False               False                 False
# 524               False               False                 False
# 1015               True               False                 False
# 1236               True               False                 False
# 1036              False               False                 False
#
# [391 rows x 21 columns]

# %%
""" Vale, entonces lo que voy a hacer es sacar la cantidad de gb que tenga cada memoria, incluyendo los tb, convertirlos en gb,  
    y por otro lado, sacar el tipo de la memoria, estaba pensando en hacer un one hot encoding a través de get dummies 
    pero tengo mi hipotesis que agregar tantas variables puede darle complejidad a mi modelo"""
# Out:
# ' Vale, entonces lo que voy a hacer es sacar la cantidad de gb que tenga cada memoria, incluyendo los tb, convertirlos en gb,  \n    y por otro lado, sacar el tipo de la memoria, estaba pensando en hacer un one hot encoding a través de get dummies \n    pero tengo mi hipotesis que agregar tantas variables puede darle complejidad a mi modelo'

# %% [markdown]
# ## Función para extraer_gb

# %%
def extraer_gb(memoria):
    total_gb = 0

    # Buscar GB
    matches_gb = re.findall(r'(\d+)GB', memoria)
    for match in matches_gb:
        total_gb += int(match)

    # Buscar TB y convertir a GB (1 TB = 1024 GB)
    matches_tb = re.findall(r'(\d+)TB', memoria)
    for match in matches_tb:
        total_gb += int(match) * 1024

    return total_gb if total_gb > 0 else 0  # Devuelve 0 si no se encuentra nada

# %% [markdown]
# ## Función para códificar el tipo de memoria

# %%
def codificar_tipo_memoria(memoria):
    if 'SSD' in memoria:
        return 1
    elif 'HDD' in memoria:
        return 2
    elif 'Hybrid' in memoria:
        return 3
    elif 'Flash' in memoria:
        return 4
    else:
        return 0  # O algún otro código para tipos no listados

# %%
df_test2['Total_Memory_GB'] = df_test2['Memory'].apply(extraer_gb)
df_test2['Memory_Type_Code'] = df_test2['Memory'].apply(codificar_tipo_memoria)

# %%
df_test2
# Out:
#      Company                                Product            TypeName  \
# id
# 181       HP                           Spectre x360           Ultrabook
# 708     Acer                               Aspire 5            Notebook
# 862     Acer                         Aspire ES1-572            Notebook
# 1064      HP                         EliteBook 1040            Notebook
# 702       HP                                 ENVY -            Notebook
# ...      ...                                    ...                 ...
# 1281  Lenovo                     Legion Y520-15IKBN              Gaming
# 524   Lenovo                     IdeaPad Y700-15ISK              Gaming
# 1015      HP                                 250 G5            Notebook
# 1236      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon            Notebook
# 1036  Lenovo                         Yoga 920-13IKB  2 in 1 Convertible
#
#       Inches                           ScreenResolution  \
# id
# 181     13.3            IPS Panel 4K Ultra HD 3840x2160
# 708     15.6                                   1366x768
# 862     15.6                                   1366x768
# 1064    14.0                          Full HD 1920x1080
# 702     13.3                IPS Panel Full HD 1920x1080
# ...      ...                                        ...
# 1281    15.6                IPS Panel Full HD 1920x1080
# 524     15.6                IPS Panel Full HD 1920x1080
# 1015    15.6                                   1366x768
# 1236    15.6                          Full HD 1920x1080
# 1036    13.9  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                Cpu  Ram     Memory                       Gpu  \
# id
# 181     Intel Core i7 7500U 2.7GHz   16  512GB SSD     Intel HD Graphics 620
# 708    AMD A12-Series 9720P 2.7GHz    8  256GB SSD         AMD Radeon RX 540
# 862     Intel Core i3 6006U 2.0GHz    4  500GB HDD     Intel HD Graphics 520
# 1064    Intel Core i5 6200U 2.3GHz    8  256GB SSD     Intel HD Graphics 520
# 702     Intel Core i5 7200U 2.5GHz    8  256GB SSD     Intel HD Graphics 620
# ...                            ...  ...        ...                       ...
# 1281   Intel Core i7 7700HQ 2.8GHz    8  256GB SSD  Nvidia GeForce GTX 1050M
# 524    Intel Core i7 6700HQ 2.6GHz   16  512GB SSD    Nvidia GeForce GTX 960
# 1015    Intel Core i5 7200U 2.5GHz    4  500GB HDD     Intel HD Graphics 620
# 1236  AMD E-Series E2-9000e 1.5GHz    4  500GB HDD             AMD Radeon R2
# 1036    Intel Core i7 8550U 1.8GHz    8  512GB SSD    Intel UHD Graphics 620
#
#            OpSys  Weight/kg OpSys_Grouped Company_Grouped  Pixeles_Total  \
# id
# 181   Windows 10       1.30       Windows              HP        8294400
# 708   Windows 10       2.20       Windows            Acer        1049088
# 862        Linux       2.40      Other OS            Acer        1049088
# 1064   Windows 7       1.43       Windows              HP        2073600
# 702   Windows 10       1.34       Windows              HP        2073600
# ...          ...        ...           ...             ...            ...
# 1281       No OS       2.40   No OS/Other          Lenovo        2073600
# 524   Windows 10       3.31       Windows          Lenovo        2073600
# 1015       No OS       1.96   No OS/Other              HP        1049088
# 1236  Windows 10       2.10       Windows              HP        2073600
# 1036  Windows 10       1.37       Windows          Lenovo        2073600
#
#         IPS  Touchscreen  Total_Memory_GB  Memory_Type_Code
# id
# 181    True        False              512                 1
# 708   False        False              256                 1
# 862   False        False              500                 2
# 1064  False        False              256                 1
# 702    True        False              256                 1
# ...     ...          ...              ...               ...
# 1281   True        False              256                 1
# 524    True        False              512                 1
# 1015  False        False              500                 2
# 1236  False        False              500                 2
# 1036   True         True              512                 1
#
# [391 rows x 18 columns]

# %%
df_encoded_test = pd.get_dummies(df_test2, columns=['TypeName'])
df_encoded_test
# Out:
#      Company                                Product  Inches  \
# id
# 181       HP                           Spectre x360    13.3
# 708     Acer                               Aspire 5    15.6
# 862     Acer                         Aspire ES1-572    15.6
# 1064      HP                         EliteBook 1040    14.0
# 702       HP                                 ENVY -    13.3
# ...      ...                                    ...     ...
# 1281  Lenovo                     Legion Y520-15IKBN    15.6
# 524   Lenovo                     IdeaPad Y700-15ISK    15.6
# 1015      HP                                 250 G5    15.6
# 1236      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon    15.6
# 1036  Lenovo                         Yoga 920-13IKB    13.9
#
#                                ScreenResolution                           Cpu  \
# id
# 181             IPS Panel 4K Ultra HD 3840x2160    Intel Core i7 7500U 2.7GHz
# 708                                    1366x768   AMD A12-Series 9720P 2.7GHz
# 862                                    1366x768    Intel Core i3 6006U 2.0GHz
# 1064                          Full HD 1920x1080    Intel Core i5 6200U 2.3GHz
# 702                 IPS Panel Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# ...                                         ...                           ...
# 1281                IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
# 524                 IPS Panel Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 1015                                   1366x768    Intel Core i5 7200U 2.5GHz
# 1236                          Full HD 1920x1080  AMD E-Series E2-9000e 1.5GHz
# 1036  IPS Panel Full HD / Touchscreen 1920x1080    Intel Core i7 8550U 1.8GHz
#
#       Ram     Memory                       Gpu       OpSys  Weight/kg  ...  \
# id                                                                     ...
# 181    16  512GB SSD     Intel HD Graphics 620  Windows 10       1.30  ...
# 708     8  256GB SSD         AMD Radeon RX 540  Windows 10       2.20  ...
# 862     4  500GB HDD     Intel HD Graphics 520       Linux       2.40  ...
# 1064    8  256GB SSD     Intel HD Graphics 520   Windows 7       1.43  ...
# 702     8  256GB SSD     Intel HD Graphics 620  Windows 10       1.34  ...
# ...   ...        ...                       ...         ...        ...  ...
# 1281    8  256GB SSD  Nvidia GeForce GTX 1050M       No OS       2.40  ...
# 524    16  512GB SSD    Nvidia GeForce GTX 960  Windows 10       3.31  ...
# 1015    4  500GB HDD     Intel HD Graphics 620       No OS       1.96  ...
# 1236    4  500GB HDD             AMD Radeon R2  Windows 10       2.10  ...
# 1036    8  512GB SSD    Intel UHD Graphics 620  Windows 10       1.37  ...
#
#         IPS Touchscreen  Total_Memory_GB  Memory_Type_Code  \
# id
# 181    True       False              512                 1
# 708   False       False              256                 1
# 862   False       False              500                 2
# 1064  False       False              256                 1
# 702    True       False              256                 1
# ...     ...         ...              ...               ...
# 1281   True       False              256                 1
# 524    True       False              512                 1
# 1015  False       False              500                 2
# 1236  False       False              500                 2
# 1036   True        True              512                 1
#
#       TypeName_2 in 1 Convertible  TypeName_Gaming  TypeName_Netbook  \
# id
# 181                         False            False             False
# 708                         False            False             False
# 862                         False            False             False
# 1064                        False            False             False
# 702                         False            False             False
# ...                           ...              ...               ...
# 1281                        False             True             False
# 524                         False             True             False
# 1015                        False            False             False
# 1236                        False            False             False
# 1036                         True            False             False
#
#       TypeName_Notebook  TypeName_Ultrabook  TypeName_Workstation
# id
# 181               False                True                 False
# 708                True               False                 False
# 862                True               False                 False
# 1064               True               False                 False
# 702                True               False                 False
# ...                 ...                 ...                   ...
# 1281              False               False                 False
# 524               False               False                 False
# 1015               True               False                 False
# 1236               True               False                 False
# 1036              False               False                 False
#
# [391 rows x 23 columns]

# %%
# # Detallo de mejor forma los valores unicos que tengo en gpu
# valores_unicos_gpu = df_train['Gpu'].unique()
# for i, gpu in enumerate(valores_unicos_gpu):
#     print(f"{i + 1}. {gpu}")

# %% [markdown]
# ## Función para agrupar por marcas

# %%
#  Agrupar por marcas
def asignar_marca_gpu(gpu):
    if 'Intel' in gpu:
        return 'Intel'
    elif 'Nvidia' in gpu:
        return 'Nvidia'
    elif 'AMD' in gpu:
        return 'AMD'
    else:
        return 'Otro'

# %%
# Aplico la función
df_test2['GPU_Marca'] = df_test2['Gpu'].apply(asignar_marca_gpu)

# %%
df_encoded_test.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight/kg', 'OpSys_Grouped',
#        'Company_Grouped', 'Pixeles_Total', 'IPS', 'Touchscreen',
#        'Total_Memory_GB', 'Memory_Type_Code', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation'],
#       dtype='object')

# %%
# Paso 2: Aplicar codificación one-hot
marca_gpu_dummies = pd.get_dummies(df_test2['GPU_Marca'], prefix='GPU')

# Unir las dummies con tu DataFrame original
df_encoded_test_2 = pd.concat([df_encoded_test, marca_gpu_dummies], axis=1)
df_encoded_test_2
# Out:
#      Company                                Product  Inches  \
# id
# 181       HP                           Spectre x360    13.3
# 708     Acer                               Aspire 5    15.6
# 862     Acer                         Aspire ES1-572    15.6
# 1064      HP                         EliteBook 1040    14.0
# 702       HP                                 ENVY -    13.3
# ...      ...                                    ...     ...
# 1281  Lenovo                     Legion Y520-15IKBN    15.6
# 524   Lenovo                     IdeaPad Y700-15ISK    15.6
# 1015      HP                                 250 G5    15.6
# 1236      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon    15.6
# 1036  Lenovo                         Yoga 920-13IKB    13.9
#
#                                ScreenResolution                           Cpu  \
# id
# 181             IPS Panel 4K Ultra HD 3840x2160    Intel Core i7 7500U 2.7GHz
# 708                                    1366x768   AMD A12-Series 9720P 2.7GHz
# 862                                    1366x768    Intel Core i3 6006U 2.0GHz
# 1064                          Full HD 1920x1080    Intel Core i5 6200U 2.3GHz
# 702                 IPS Panel Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# ...                                         ...                           ...
# 1281                IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
# 524                 IPS Panel Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 1015                                   1366x768    Intel Core i5 7200U 2.5GHz
# 1236                          Full HD 1920x1080  AMD E-Series E2-9000e 1.5GHz
# 1036  IPS Panel Full HD / Touchscreen 1920x1080    Intel Core i7 8550U 1.8GHz
#
#       Ram     Memory                       Gpu       OpSys  Weight/kg  ...  \
# id                                                                     ...
# 181    16  512GB SSD     Intel HD Graphics 620  Windows 10       1.30  ...
# 708     8  256GB SSD         AMD Radeon RX 540  Windows 10       2.20  ...
# 862     4  500GB HDD     Intel HD Graphics 520       Linux       2.40  ...
# 1064    8  256GB SSD     Intel HD Graphics 520   Windows 7       1.43  ...
# 702     8  256GB SSD     Intel HD Graphics 620  Windows 10       1.34  ...
# ...   ...        ...                       ...         ...        ...  ...
# 1281    8  256GB SSD  Nvidia GeForce GTX 1050M       No OS       2.40  ...
# 524    16  512GB SSD    Nvidia GeForce GTX 960  Windows 10       3.31  ...
# 1015    4  500GB HDD     Intel HD Graphics 620       No OS       1.96  ...
# 1236    4  500GB HDD             AMD Radeon R2  Windows 10       2.10  ...
# 1036    8  512GB SSD    Intel UHD Graphics 620  Windows 10       1.37  ...
#
#      TypeName_2 in 1 Convertible TypeName_Gaming  TypeName_Netbook  \
# id
# 181                        False           False             False
# 708                        False           False             False
# 862                        False           False             False
# 1064                       False           False             False
# 702                        False           False             False
# ...                          ...             ...               ...
# 1281                       False            True             False
# 524                        False            True             False
# 1015                       False           False             False
# 1236                       False           False             False
# 1036                        True           False             False
#
#       TypeName_Notebook  TypeName_Ultrabook  TypeName_Workstation  GPU_AMD  \
# id
# 181               False                True                 False    False
# 708                True               False                 False     True
# 862                True               False                 False    False
# 1064               True               False                 False    False
# 702                True               False                 False    False
# ...                 ...                 ...                   ...      ...
# 1281              False               False                 False    False
# 524               False               False                 False    False
# 1015               True               False                 False    False
# 1236               True               False                 False     True
# 1036              False               False                 False    False
#
#       GPU_Intel  GPU_Nvidia  GPU_Otro
# id
# 181        True       False     False
# 708       False       False     False
# 862        True       False     False
# 1064       True       False     False
# 702        True       False     False
# ...         ...         ...       ...
# 1281      False        True     False
# 524       False        True     False
# 1015       True       False     False
# 1236      False       False     False
# 1036       True       False     False
#
# [391 rows x 27 columns]

# %%
# Crear una variable dummy para indicar si la GPU es integrada o dedicada
df_test2['GPU_Integrada'] = df_test2['Gpu'].apply(lambda x: 1 if 'Intel' in x else 0)
df_test2['GPU_Dedicada'] = df_test2['Gpu'].apply(lambda x: 1 if 'Nvidia' in x or 'AMD' in x else 0)

# %%
df_encoded_test_3 = pd.concat([df_encoded_test_2, df_test2['GPU_Integrada']], axis=1)
df_encoded_test_3 = pd.concat([df_encoded_test_3, df_test2['GPU_Dedicada']], axis=1)
df_encoded_test_3
# Out:
#      Company                                Product  Inches  \
# id
# 181       HP                           Spectre x360    13.3
# 708     Acer                               Aspire 5    15.6
# 862     Acer                         Aspire ES1-572    15.6
# 1064      HP                         EliteBook 1040    14.0
# 702       HP                                 ENVY -    13.3
# ...      ...                                    ...     ...
# 1281  Lenovo                     Legion Y520-15IKBN    15.6
# 524   Lenovo                     IdeaPad Y700-15ISK    15.6
# 1015      HP                                 250 G5    15.6
# 1236      HP  15-bw000nv (E2-9000e/4GB/500GB/Radeon    15.6
# 1036  Lenovo                         Yoga 920-13IKB    13.9
#
#                                ScreenResolution                           Cpu  \
# id
# 181             IPS Panel 4K Ultra HD 3840x2160    Intel Core i7 7500U 2.7GHz
# 708                                    1366x768   AMD A12-Series 9720P 2.7GHz
# 862                                    1366x768    Intel Core i3 6006U 2.0GHz
# 1064                          Full HD 1920x1080    Intel Core i5 6200U 2.3GHz
# 702                 IPS Panel Full HD 1920x1080    Intel Core i5 7200U 2.5GHz
# ...                                         ...                           ...
# 1281                IPS Panel Full HD 1920x1080   Intel Core i7 7700HQ 2.8GHz
# 524                 IPS Panel Full HD 1920x1080   Intel Core i7 6700HQ 2.6GHz
# 1015                                   1366x768    Intel Core i5 7200U 2.5GHz
# 1236                          Full HD 1920x1080  AMD E-Series E2-9000e 1.5GHz
# 1036  IPS Panel Full HD / Touchscreen 1920x1080    Intel Core i7 8550U 1.8GHz
#
#       Ram     Memory                       Gpu       OpSys  Weight/kg  ...  \
# id                                                                     ...
# 181    16  512GB SSD     Intel HD Graphics 620  Windows 10       1.30  ...
# 708     8  256GB SSD         AMD Radeon RX 540  Windows 10       2.20  ...
# 862     4  500GB HDD     Intel HD Graphics 520       Linux       2.40  ...
# 1064    8  256GB SSD     Intel HD Graphics 520   Windows 7       1.43  ...
# 702     8  256GB SSD     Intel HD Graphics 620  Windows 10       1.34  ...
# ...   ...        ...                       ...         ...        ...  ...
# 1281    8  256GB SSD  Nvidia GeForce GTX 1050M       No OS       2.40  ...
# 524    16  512GB SSD    Nvidia GeForce GTX 960  Windows 10       3.31  ...
# 1015    4  500GB HDD     Intel HD Graphics 620       No OS       1.96  ...
# 1236    4  500GB HDD             AMD Radeon R2  Windows 10       2.10  ...
# 1036    8  512GB SSD    Intel UHD Graphics 620  Windows 10       1.37  ...
#
#      TypeName_Netbook TypeName_Notebook  TypeName_Ultrabook  \
# id
# 181             False             False                True
# 708             False              True               False
# 862             False              True               False
# 1064            False              True               False
# 702             False              True               False
# ...               ...               ...                 ...
# 1281            False             False               False
# 524             False             False               False
# 1015            False              True               False
# 1236            False              True               False
# 1036            False             False               False
#
#       TypeName_Workstation  GPU_AMD  GPU_Intel  GPU_Nvidia  GPU_Otro  \
# id
# 181                  False    False       True       False     False
# 708                  False     True      False       False     False
# 862                  False    False       True       False     False
# 1064                 False    False       True       False     False
# 702                  False    False       True       False     False
# ...                    ...      ...        ...         ...       ...
# 1281                 False    False      False        True     False
# 524                  False    False      False        True     False
# 1015                 False    False       True       False     False
# 1236                 False     True      False       False     False
# 1036                 False    False       True       False     False
#
#       GPU_Integrada  GPU_Dedicada
# id
# 181               1             0
# 708               0             1
# 862               1             0
# 1064              1             0
# 702               1             0
# ...             ...           ...
# 1281              0             1
# 524               0             1
# 1015              1             0
# 1236              0             1
# 1036              1             0
#
# [391 rows x 29 columns]

# %% [markdown]
# ## Voy a codificar las gpu con una función

# %%
# def codificar_gpu(gpu):
#     if 'Intel' in gpu:
#         return 1  # Intel (Integradas)
#     elif 'Nvidia' in gpu:
#         return 2  # Nvidia (Dedicadas)
#     elif 'AMD' in gpu:
#         return 3  # AMD (Dedicadas)
#     else:
#         return 4  # Otros

# df2_t['COD_GPU'] = df2_t['Gpu'].apply(codificar_gpu)

# %% [markdown]
# La codificación una mierda, exploraremos otro método

# %% [markdown]
# ## Train

# %%
# Para este primer modelo voy a limpiar algunas columnas y cambiar su dtype

#Primero ram
df_train['Ram'] = df_train['Ram'].str.replace('GB', '').astype(int)

# Ahora voy a transformar Weight
df_train['Weight'] = df_train['Weight'].str.replace('kg', '').astype(float)

# Voy a renombar  Weight y le pondré Weigh/kg para que sea más descriptiva y se entienda que los valores numericos hacen referencia a su peso en kg

df_train = df_train.rename(columns={'Weight': 'Weight/kg'})

# %%
# Me haré un segundo DF donde desecho las primeras dos columnas porque no las necesito para la predicción

df2_train = df_train.drop(['laptop_ID'], axis=1)

# Voy a ver si puedo sacarle provecho al typeName
# df2 = df2.drop(['TypeName'], axis=1)

# %%
# Agrupo varias variables
df2_train['OpSys_Grouped'] = df2_train['OpSys'].apply(group_os)
df2_train['Company_Grouped'] = df2_train['Company'].apply(agrupar_marcas)

# Extraigo y creo otras variables
# Extraer los píxeles
df2_train['Pixeles_Total'] = df2_train['ScreenResolution'].apply(extraer_pixeles)

# Extraer características de la pantalla
df2_train[['IPS', 'Touchscreen']] = df2_train['ScreenResolution'].apply(screen_featuring)

# Extraer cantidad y codificar las memorias
df2_train['Total_Memory_GB'] = df2_train['Memory'].apply(extraer_gb)
df2_train['Memory_Type_Code'] = df2_train['Memory'].apply(codificar_tipo_memoria)

# Asigno marca GPU
df2_train['GPU_Marca'] = df2_train['Gpu'].apply(asignar_marca_gpu)

# Crear una variable dummy para indicar si la GPU es integrada o dedicada
df2_train['GPU_Integrada'] = df2_train['Gpu'].apply(lambda x: 1 if 'Intel' in x else 0)
df2_train['GPU_Dedicada'] = df2_train['Gpu'].apply(lambda x: 1 if 'Nvidia' in x or 'AMD' in x else 0)

# %%
#  Aplicar One-Hot Encoding a la variable TypeName, al ser tan pocos no hizo falta agruparlos primero
df_encoded_train = pd.get_dummies(df2_train, columns=['TypeName'])
df_encoded_train
# Out:
#       Company                     Product  Inches  \
# id
# 268      Dell               Inspiron 5567    15.6
# 347      Asus  X541NA (N4200/4GB/1TB/W10)    15.6
# 353   Toshiba           Portege Z30-C-1CW    13.3
# 578      Dell                Alienware 17    15.6
# 42       Dell              Latitude E7270    12.5
# ...       ...                         ...     ...
# 89       Acer       Chromebook C738T-C2EJ    11.6
# 716   Toshiba           Portege Z30-C-16H    13.3
# 517      Acer              Aspire ES1-523    15.6
# 891      Dell               Latitude 7480    14.0
# 1179     Dell               Inspiron 3567    15.6
#
#                      ScreenResolution                                   Cpu  \
# id
# 268                          1366x768            Intel Core i7 7500U 2.7GHz
# 347                          1366x768  Intel Pentium Quad Core N4200 1.1GHz
# 353                 Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 578   IPS Panel 4K Ultra HD 3840x2160           Intel Core i7 7700HQ 2.8GHz
# 42    Full HD / Touchscreen 1920x1080            Intel Core i5 6300U 2.4GHz
# ...                               ...                                   ...
# 89     IPS Panel Touchscreen 1366x768  Intel Celeron Dual Core N3060 1.6GHz
# 716                 Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 517                          1366x768             AMD A8-Series 7410 2.2GHz
# 891                 Full HD 1920x1080            Intel Core i7 7600U 2.8GHz
# 1179                         1366x768            Intel Core i7 7500U 2.7GHz
#
#       Ram                Memory                      Gpu       OpSys  \
# id
# 268     8               1TB HDD       AMD Radeon R7 M445  Windows 10
# 347     4               1TB HDD    Intel HD Graphics 505  Windows 10
# 353     8             256GB SSD    Intel HD Graphics 520   Windows 7
# 578    16  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10
# 42      8             256GB SSD    Intel HD Graphics 520   Windows 7
# ...   ...                   ...                      ...         ...
# 89      4    32GB Flash Storage    Intel HD Graphics 400   Chrome OS
# 716     4             128GB SSD    Intel HD Graphics 520  Windows 10
# 517     8               1TB HDD            AMD Radeon R5  Windows 10
# 891     8             256GB SSD    Intel HD Graphics 620  Windows 10
# 1179    8               1TB HDD       AMD Radeon R5 M430       Linux
#
#       Weight/kg  ...  Memory_Type_Code GPU_Marca GPU_Integrada  GPU_Dedicada  \
# id               ...
# 268        2.36  ...                 2       AMD             0             1
# 347        2.00  ...                 2     Intel             1             0
# 353        1.20  ...                 1     Intel             1             0
# 578        4.42  ...                 1    Nvidia             0             1
# 42         1.26  ...                 1     Intel             1             0
# ...         ...  ...               ...       ...           ...           ...
# 89         1.25  ...                 4     Intel             1             0
# 716        1.20  ...                 1     Intel             1             0
# 517        2.40  ...                 2       AMD             0             1
# 891        1.36  ...                 1     Intel             1             0
# 1179       2.30  ...                 2       AMD             0             1
#
#       TypeName_2 in 1 Convertible  TypeName_Gaming  TypeName_Netbook  \
# id
# 268                         False            False             False
# 347                         False            False             False
# 353                         False            False             False
# 578                         False             True             False
# 42                          False            False             False
# ...                           ...              ...               ...
# 89                           True            False             False
# 716                         False            False             False
# 517                         False            False             False
# 891                         False            False             False
# 1179                        False            False             False
#
#       TypeName_Notebook TypeName_Ultrabook  TypeName_Workstation
# id
# 268                True              False                 False
# 347                True              False                 False
# 353                True              False                 False
# 578               False              False                 False
# 42                False               True                 False
# ...                 ...                ...                   ...
# 89                False              False                 False
# 716                True              False                 False
# 517                True              False                 False
# 891               False               True                 False
# 1179               True              False                 False
#
# [912 rows x 27 columns]

# %%
# Paso 2: Aplicar codificación one-hot
marca_gpu_dummies_train = pd.get_dummies(df2_train['GPU_Marca'], prefix='GPU')

# Unir las dummies con tu DataFrame original
df_encoded_train_2 = pd.concat([df_encoded_train, marca_gpu_dummies_train], axis=1)
df_encoded_train_2
# Out:
#       Company                     Product  Inches  \
# id
# 268      Dell               Inspiron 5567    15.6
# 347      Asus  X541NA (N4200/4GB/1TB/W10)    15.6
# 353   Toshiba           Portege Z30-C-1CW    13.3
# 578      Dell                Alienware 17    15.6
# 42       Dell              Latitude E7270    12.5
# ...       ...                         ...     ...
# 89       Acer       Chromebook C738T-C2EJ    11.6
# 716   Toshiba           Portege Z30-C-16H    13.3
# 517      Acer              Aspire ES1-523    15.6
# 891      Dell               Latitude 7480    14.0
# 1179     Dell               Inspiron 3567    15.6
#
#                      ScreenResolution                                   Cpu  \
# id
# 268                          1366x768            Intel Core i7 7500U 2.7GHz
# 347                          1366x768  Intel Pentium Quad Core N4200 1.1GHz
# 353                 Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 578   IPS Panel 4K Ultra HD 3840x2160           Intel Core i7 7700HQ 2.8GHz
# 42    Full HD / Touchscreen 1920x1080            Intel Core i5 6300U 2.4GHz
# ...                               ...                                   ...
# 89     IPS Panel Touchscreen 1366x768  Intel Celeron Dual Core N3060 1.6GHz
# 716                 Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 517                          1366x768             AMD A8-Series 7410 2.2GHz
# 891                 Full HD 1920x1080            Intel Core i7 7600U 2.8GHz
# 1179                         1366x768            Intel Core i7 7500U 2.7GHz
#
#       Ram                Memory                      Gpu       OpSys  \
# id
# 268     8               1TB HDD       AMD Radeon R7 M445  Windows 10
# 347     4               1TB HDD    Intel HD Graphics 505  Windows 10
# 353     8             256GB SSD    Intel HD Graphics 520   Windows 7
# 578    16  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10
# 42      8             256GB SSD    Intel HD Graphics 520   Windows 7
# ...   ...                   ...                      ...         ...
# 89      4    32GB Flash Storage    Intel HD Graphics 400   Chrome OS
# 716     4             128GB SSD    Intel HD Graphics 520  Windows 10
# 517     8               1TB HDD            AMD Radeon R5  Windows 10
# 891     8             256GB SSD    Intel HD Graphics 620  Windows 10
# 1179    8               1TB HDD       AMD Radeon R5 M430       Linux
#
#       Weight/kg  ...  GPU_Dedicada TypeName_2 in 1 Convertible  \
# id               ...
# 268        2.36  ...             1                       False
# 347        2.00  ...             0                       False
# 353        1.20  ...             0                       False
# 578        4.42  ...             1                       False
# 42         1.26  ...             0                       False
# ...         ...  ...           ...                         ...
# 89         1.25  ...             0                        True
# 716        1.20  ...             0                       False
# 517        2.40  ...             1                       False
# 891        1.36  ...             0                       False
# 1179       2.30  ...             1                       False
#
#      TypeName_Gaming  TypeName_Netbook  TypeName_Notebook  TypeName_Ultrabook  \
# id
# 268            False             False               True               False
# 347            False             False               True               False
# 353            False             False               True               False
# 578             True             False              False               False
# 42             False             False              False                True
# ...              ...               ...                ...                 ...
# 89             False             False              False               False
# 716            False             False               True               False
# 517            False             False               True               False
# 891            False             False              False                True
# 1179           False             False               True               False
#
#       TypeName_Workstation  GPU_AMD GPU_Intel  GPU_Nvidia
# id
# 268                  False     True     False       False
# 347                  False    False      True       False
# 353                  False    False      True       False
# 578                  False    False     False        True
# 42                   False    False      True       False
# ...                    ...      ...       ...         ...
# 89                   False    False      True       False
# 716                  False    False      True       False
# 517                  False     True     False       False
# 891                  False    False      True       False
# 1179                 False     True     False       False
#
# [912 rows x 30 columns]

# %%
df_encoded_train_2.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight/kg', 'Price_euros', 'OpSys_Grouped',
#        'Company_Grouped', 'Pixeles_Total', 'IPS', 'Touchscreen',
#        'Total_Memory_GB', 'Memory_Type_Code', 'GPU_Marca', 'GPU_Integrada',
#        'GPU_Dedicada', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming',
#        'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook',
#        'TypeName_Workstation', 'GPU_AMD', 'GPU_Intel', 'GPU_Nvidia'],
#       dtype='object')

# %%
df_encoded_test_3.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight/kg', 'OpSys_Grouped',
#        'Company_Grouped', 'Pixeles_Total', 'IPS', 'Touchscreen',
#        'Total_Memory_GB', 'Memory_Type_Code', 'TypeName_2 in 1 Convertible',
#        'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook',
#        'TypeName_Ultrabook', 'TypeName_Workstation', 'GPU_AMD', 'GPU_Intel',
#        'GPU_Nvidia', 'GPU_Otro', 'GPU_Integrada', 'GPU_Dedicada'],
#       dtype='object')

# %%
m_corr = df_encoded_train_2[['Ram', 'Weight/kg', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'TypeName_2 in 1 Convertible', 'Pixeles_Total', 'IPS', 'Touchscreen', "Total_Memory_GB", "Memory_Type_Code", 'GPU_AMD', 'GPU_Intel', 'GPU_Nvidia','GPU_Integrada', 'GPU_Dedicada', 'Price_euros' ]].corr()

# %%
# sns.pairplot(df_encoded_train_2, kind='scatter')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(m_corr, annot=True, fmt=".2f", annot_kws={'size': 10}, cmap='coolwarm');

# %%
"""Corregí un fallo que tenía al agrupar los sistemas operativos, algunos de Mac los estaba enviando a OS """
# df2[df2['OpSys_Grouped'] == 'Mac']
# # df2[df2['Company']== 'Apple']
# Out:
# 'Corregí un fallo que tenía al agrupar los sistemas operativos, algunos de Mac los estaba enviando a OS '

# %%
# sns.heatmap(df_encoded[['TypeName_2 in 1 Convertible', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'Price_euros']].corr(), annot= True)
# sns.heatmap(df_encoded.corr(numeric_only=True), annot= True, cmap='coolwarm')
# df_encoded['Gpu'].unique()

# %% [markdown]
# ## Pasos que si o si debéis realizar para poder participar en la competición:

# %% [markdown]
# ### 1. Definir X e y

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
df_encoded_train.columns
# Out:
# Index(['Company', 'Product', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight/kg', 'Price_euros', 'OpSys_Grouped',
#        'Company_Grouped', 'Pixeles_Total', 'IPS', 'Touchscreen',
#        'Total_Memory_GB', 'Memory_Type_Code', 'GPU_Marca', 'GPU_Integrada',
#        'GPU_Dedicada', 'TypeName_2 in 1 Convertible', 'TypeName_Gaming',
#        'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook',
#        'TypeName_Workstation'],
#       dtype='object')

# %%
# X = df_encoded_train.drop(['Price_euros'], axis=1)
# y = df_encoded_train['Price_euros']

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
X_train = df_encoded_train_2[['Ram', 'Weight/kg', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'TypeName_2 in 1 Convertible', 'Pixeles_Total', 'IPS', 'Touchscreen', "Total_Memory_GB", "Memory_Type_Code",'GPU_Integrada', 'GPU_Dedicada']]
X_test = df_encoded_test_3[['Ram', 'Weight/kg', 'TypeName_Gaming', 'TypeName_Netbook', 'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation', 'TypeName_2 in 1 Convertible', 'Pixeles_Total', 'IPS', 'Touchscreen', "Total_Memory_GB", "Memory_Type_Code", 'GPU_Integrada', 'GPU_Dedicada']]
y_train = df_encoded_train_2['Price_euros']
y_test = sample['Price_euros']

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (912, 15)
# (391, 15)
# (912,)
# (391,)

# %% [markdown]
# ### 3. Crear y entrenar el modelo

# %%
#creating LinearRegression Object
lm = LinearRegression()
#Training the Data Model
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Hago mis predicciones
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([2698.21547765,  855.23883293,  522.14272442, 1023.05231257,
#        1029.9038111 , 1850.21066911, 1864.10281677,  483.61363335,
#        5601.54039985, 1392.6535236 , 1452.25295315,  396.36256546,
#         363.4963056 ,  732.86485315,  587.57197996, 1219.65296654,
#         571.50381603, 1395.62922529, 1233.04362412, 1417.53788108,
#        1505.98928038, 1266.11497325, 1520.81682747, 1446.79750006,
#        1864.8236439 ,  833.17869167,  784.5092027 ,  396.36256546,
#        1151.6228861 ,  380.57842814, 1406.58205976, 1036.35116475,
#        1810.26911302,  786.92019495,  488.57313616, 1869.78314671,
#         962.24164038,  793.2757432 , 3176.9272274 ,  687.92135114,
#         507.264216  ,  937.44412634, 1344.23664648, 1852.82903177,
#        1327.89236784, 1531.68367851,  585.09222856, 3164.03396768,
#         480.56917251, 1838.26245175,  978.51619425,  809.80266702,
#        1054.09438402,  512.2237188 , 1234.12733007,  595.32910739,
#         724.92964866,  108.82413907, 1019.5806606 , 1279.26434542,
#        1466.72731668, 1148.18676152,  749.97976856, 1234.53147496,
#        1023.05231257, 1149.82483149,  507.264216  , 1951.90809707,
#         430.33344099, 1849.35882739,  718.52138855, 2868.04784244,
#        2029.01023237, 1379.95806428, 1015.52125296, 1046.36197576,
#        1059.75263334,  384.05008011,  954.30643589,  937.87179943,
#         401.32584073, 2039.62135456, 1293.48682098,  499.82496179,
#        1172.85694278, 1446.70618564, 1859.86414109,  626.06208509,
#        2827.37991942,  848.58868304,  628.3417971 ,  522.14272442,
#        1279.26434542, 1123.26191471, 2445.10081391,  551.15409714,
#        1291.36154732, 1111.94686364, 1033.46726846, 1095.75096879,
#         748.58727017,  623.7261474 , 1665.95763681, 1044.2435855 ,
#         750.73890083, 1430.83673327,  837.32841148,  762.82190939,
#        1033.96321874, 1573.85997931, 1031.84482848, 1063.33819633,
#         512.2237188 ,  963.72949122,  947.85908224, 1864.8236439 ,
#         962.24164038,  959.69312981,  947.58752684, 1752.29408368,
#         490.48817812, 1227.12128875,  826.07722089, 1886.4205794 ,
#         271.37200656, 1322.69677281, 1908.46726861, 1436.38399175,
#        1841.51398071, 1357.22171159,  898.19577697, 1046.36197576,
#         412.72892472, 1454.23675427,  504.28851431,  415.70462641,
#         380.63843339, 1945.57173427, 1249.93500166,  692.88085395,
#         749.13940703, 1905.64324843, 2017.84116894, 1043.38627408,
#        2090.21276752,  944.38743027,  939.26784488,  748.23931186,
#        1148.13844932, 2791.08519112,  620.11343857,  534.24988964,
#        1695.90336951,  582.61247715, 1136.45577256, 1057.67702683,
#        2300.64340038,  770.19843801,  639.0283084 , 1248.11178641,
#        2214.18192426,  794.9241586 , 1291.50301985, 2184.9208577 ,
#        1864.8236439 , 1574.35737717, 1451.84880826, 2043.94341401,
#        1430.83673327,  483.04892391, 2073.68848174, 2177.5826923 ,
#        2207.02447448,  572.69347154, 2801.9042919 , 1430.02699591,
#        1080.54504473, 1032.87951279, 3181.66185335, 1437.9622004 ,
#         488.57313616, 1909.02309501,  651.66765299,  373.13917393,
#         655.89061794, 1600.29881745, 1011.64545611,  789.96465579,
#         758.50627578, 2046.69664303, 1854.90463829,  806.23920966,
#        1246.37154431,  916.34017198,  475.6096697 , 1691.43981698,
#        1931.01677698,  968.68899403, 1403.96857467, 1856.30068374,
#         718.52138855, 1967.55359265,  909.71362427, 1986.91505029,
#        1305.45790491,  359.04820758,  613.52219503,  488.57313616,
#         796.41200944, 2027.26422428, 1138.14042313,  654.89871738,
#         979.13761443,  952.32263477,  507.264216  , 1326.46157882,
#         488.57313616, 1480.98217   ,  998.44200661,  806.23920966,
#        2398.12704366, 1459.78401275, 1893.49695479, 1442.29804811,
#         932.41634634, 2179.96135489, 2288.67704535,  755.18261579,
#         570.21372013,  758.50627578,  750.22311298,  938.84017179,
#        1919.78231967, 1305.45790491,  985.55130357,  957.28213757,
#        1614.5895702 ,  977.1201488 ,  396.36256546,  574.74967669,
#        2529.9152993 ,  611.78727205,  799.05535968, 1249.93500166,
#        2221.92796738, 1434.98649872, 1051.32147857, 1968.18265095,
#         590.05173136, 1596.17774194, 1561.55302768, 1026.02801425,
#        1887.93051086, 1033.46726846, 1446.39335517, 1053.30527969,
#         483.80979964, 1246.02737997, 1451.22515316,  910.69904028,
#        1317.33312512,  764.92237838,  702.79985957,  479.57727194,
#        1525.08060264, 1251.33104711, 2292.08899832, 1863.32840205,
#        1231.15162839, 1440.93790208,  953.009363  ,  488.57313616,
#        1043.38627408, 1249.93500166, 1253.12784631,  386.51378817,
#        2060.66477867,  476.95276738, 1748.40984697,  505.77636516,
#        2491.18741979, 1052.31337913,  789.63226282,  617.28613776,
#         107.78153945,  857.50511958, 1434.98649872,  832.06373635,
#        1064.84910241, 1031.48346734,  766.20451281, 1550.80150302,
#        1480.98217   , 2298.00829529, 2288.67704535,  791.87969775,
#         916.04998708,  366.01989701, 1047.75802121,  610.98353728,
#         804.84316421, 1237.10303176,  956.10807381, 1789.39999692,
#         507.264216  , 2059.33227961, 1630.11674116, 1507.9730815 ,
#         393.96908572,  259.02394861,  742.49070472, 1901.70894217,
#         612.77917261,  383.53808649,  464.50100858,  517.67917189,
#        2050.48352966, 2257.74741232, 1940.58279373,  903.15527978,
#        1313.27371748, 1906.84489872, 1930.10691776, 2051.47398264,
#         948.01846375, 1493.68272345, 1630.1102501 ,  260.95705067,
#         488.57313616,  359.04820758, 1046.36197576,  475.6096697 ,
#         924.48065988,  253.17394335,  695.85655564,  988.57215712,
#        2032.22372708, 1225.13748763,  749.46033161, 1234.12733007,
#         693.87275451, 1951.52313764,   93.39898131, 1290.60292468,
#         952.32263477,  701.53249038,  657.37846878, 1563.63347292,
#        1535.69533589, 1264.81351009,  933.97247438, 1026.02801425,
#         491.05288756, 1217.26502053, 1049.33767744,  483.61363335,
#        1121.86586925, 1891.01720339,  502.30471319, 1471.09906382,
#         224.43652143, 1956.27984421,  597.49098557, 1060.15677823,
#        1894.3557839 ,  779.48094073,  413.224875  , 1854.67422164,
#        1138.14042313,  587.57197996,  411.32734555,  957.19033218,
#        1121.86586925, 1273.76114217,  260.46110039, 1225.13748763,
#        1454.82450994,  483.61363335,  498.83306122, 1006.17441487,
#        1225.13748763,  507.264216  , 1251.33104711,  385.02593733,
#        2024.78447287,  596.80425734, 1300.4984021 , 1942.86710601,
#         500.32091207,  515.26817965, 1217.57880761])

# %%
from sklearn import metrics

lm.score(X_test, y_test)
# Out:
# -0.8108100533989284

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
# Out:
# MAE: 678.6936033754735

# %%
from sklearn.metrics import mean_absolute_error

# Ahora voy a escalar a ver si me da mejores resultados

# Ahora voy a escalarlo
from sklearn.preprocessing import StandardScaler

# Inicializar el escalador
scaler = StandardScaler()

# Ajustar el escalador con los datos de entrenamiento y transformarlos
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Crear y entrenar el modelo de regresión lineal
lm_scaled = LinearRegression()
lm_scaled.fit(X_train_scaled, y_train)
# Hacer predicciones con los datos de prueba escalados
predictions_scaled = lm_scaled.predict(X_test_scaled)

# Evaluar el modelo
print('MAE:', mean_absolute_error(y_test, predictions_scaled))

score_scaled = lm_scaled.score(X_test_scaled, y_test)
print("Coeficiente de determinación (R^2) en datos escalados:", round(score_scaled), 2)
# Out:
# MAE: 12004400241477.611
# Coeficiente de determinación (R^2) en datos escalados: -129414038933085926457344 2

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Inicializar el escalador
scaler = StandardScaler()

# Escalar solo las variables numéricas continuas, no las dummies
# Identifica las columnas que necesitas escalar
columnas_para_escalar = ['Ram', 'Weight/kg', 'Pixeles_Total', "Total_Memory_GB"]

# Escalar solo esas columnas
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

X_train_scaled[columnas_para_escalar] = scaler.fit_transform(X_train[columnas_para_escalar])
X_test_scaled[columnas_para_escalar] = scaler.transform(X_test[columnas_para_escalar])

# Entrenar el modelo
lm_scaled = LinearRegression()
lm_scaled.fit(X_train_scaled, y_train)

# Evaluar el modelo
predictions_scaled = lm_scaled.predict(X_test_scaled)
print('MAE:', mean_absolute_error(y_test, predictions_scaled))
score_scaled = lm_scaled.score(X_test_scaled, y_test)
print("Coeficiente de determinación (R^2) en datos escalados:", score_scaled)
# Out:
# MAE: 678.6936033722542
# Coeficiente de determinación (R^2) en datos escalados: -0.8108100533795801

# %%
dicccionario ={'id':df_encoded_test.index,"Price_euros": predictions_scaled}

# %%
df_scal = pd.DataFrame(dicccionario)
df_scal
# Out:
#        id  Price_euros
# 0     181  2698.215478
# 1     708   855.238833
# 2     862   522.142724
# 3    1064  1023.052313
# 4     702  1029.903811
# ..    ...          ...
# 386  1281  1300.498402
# 387   524  1942.867106
# 388  1015   500.320912
# 389  1236   515.268180
# 390  1036  1217.578808
#
# [391 rows x 2 columns]

# %% [markdown]
# ### 5. Pásale el CHEQUEATOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                df_to_submit.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
df_scal.to_csv('quinto_modelo_3.csv', index=False)
